# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных" data-toc-modified-id="Изучение-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных</a></span></li><li><span><a href="#Предобработка-данных." data-toc-modified-id="Предобработка-данных.-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных.</a></span><ul class="toc-item"><li><span><a href="#Поиск-дубликатов." data-toc-modified-id="Поиск-дубликатов.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Поиск дубликатов.</a></span></li><li><span><a href="#Поиск-и-обработка-пропусков" data-toc-modified-id="Поиск-и-обработка-пропусков-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Поиск и обработка пропусков</a></span></li><li><span><a href="#Аномальные-значения" data-toc-modified-id="Аномальные-значения-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Аномальные значения</a></span></li><li><span><a href="#Добавление-новых-столбцов" data-toc-modified-id="Добавление-новых-столбцов-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Добавление новых столбцов</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Распределение-заведений-по-категориям" data-toc-modified-id="Распределение-заведений-по-категориям-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Распределение заведений по категориям</a></span></li><li><span><a href="#Количество-посадочных-мест" data-toc-modified-id="Количество-посадочных-мест-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Количество посадочных мест</a></span></li><li><span><a href="#Сетевые-и-одиночные-заведения" data-toc-modified-id="Сетевые-и-одиночные-заведения-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Сетевые и одиночные заведения</a></span></li><li><span><a href="#Топ-15-сетевых-заведений" data-toc-modified-id="Топ-15-сетевых-заведений-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Топ 15 сетевых заведений</a></span></li><li><span><a href="#Администратиные-районы" data-toc-modified-id="Администратиные-районы-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Администратиные районы</a></span></li><li><span><a href="#Рейтинг-по-категориям" data-toc-modified-id="Рейтинг-по-категориям-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Рейтинг по категориям</a></span></li><li><span><a href="#Средний-рейтинг-заведений-по-районам" data-toc-modified-id="Средний-рейтинг-заведений-по-районам-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Средний рейтинг заведений по районам</a></span></li><li><span><a href="#Улицы-с-одним-заведением" data-toc-modified-id="Улицы-с-одним-заведением-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Улицы с одним заведением</a></span></li><li><span><a href="#Медианные-значения-среднего-чека" data-toc-modified-id="Медианные-значения-среднего-чека-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Медианные значения среднего чека</a></span></li></ul></li><li><span><a href="#Выводы." data-toc-modified-id="Выводы.-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Выводы.</a></span></li><li><span><a href="#Открытие-коффейни" data-toc-modified-id="Открытие-коффейни-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Открытие коффейни</a></span><ul class="toc-item"><li><span><a href="#Распределение-кофеен-по-округам" data-toc-modified-id="Распределение-кофеен-по-округам-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Распределение кофеен по округам</a></span></li><li><span><a href="#Круглосуточные-кофейни" data-toc-modified-id="Круглосуточные-кофейни-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Круглосуточные кофейни</a></span></li><li><span><a href="#Рейтинги-кофеен" data-toc-modified-id="Рейтинги-кофеен-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Рейтинги кофеен</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Рынок заведений общественного питания Москвы

# %% [markdown]
# # Цель исследования

# %% [markdown]
# *Подготовить исследование рынка Москвы, найти интересные особенности и презентовать полученные результаты, которые в будущем помогут в выборе подходящего инвесторам места.*

# %% [markdown]
# # Описание данных

# %% [markdown]
# Файл `moscow_places.csv:`
#
#
# `name` — название заведения;
#
# `address` — адрес заведения;
#
# `category` — категория заведения, например «кафе», «пиццерия» или «кофейня»;
#
# `hours` — информация о днях и часах работы;
#
# `lat` — широта географической точки, в которой находится заведение;
#
# `lng` — долгота географической точки, в которой находится заведение;
#
# `rating` — рейтинг заведения по оценкам пользователей в Яндекс Картах (высшая оценка — 5.0);
#
# `price` — категория цен в заведении, например «средние», «ниже среднего», «выше среднего» и так далее;
#
# `avg_bill` — строка, которая хранит среднюю стоимость заказа в виде диапазона, например:
#
# «Средний счёт: 1000–1500 ₽»;
#
# «Цена чашки капучино: 130–220 ₽»;
#
# «Цена бокала пива: 400–600 ₽».
#
# и так далее;
#
# `middle_avg_bill` — число с оценкой среднего чека, которое указано только для значений из столбца avg_bill, начинающихся с подстроки «Средний счёт»:
# Если в строке указан ценовой диапазон из двух значений, в столбец войдёт медиана этих двух значений.
# Если в строке указано одно число — цена без диапазона, то в столбец войдёт это число.
# Если значения нет или оно не начинается с подстроки «Средний счёт», то в столбец ничего не войдёт.
#
# `middle_coffee_cup` — число с оценкой одной чашки капучино, которое указано только для значений из столбца
#
# `avg_bill`, начинающихся с подстроки «Цена одной чашки капучино»:
#
# Если в строке указан ценовой диапазон из двух значений, в столбец войдёт медиана этих двух значений.
#
# Если в строке указано одно число — цена без диапазона, то в столбец войдёт это число.
#
# Если значения нет или оно не начинается с подстроки «Цена одной чашки капучино», то в столбец ничего не войдёт.
#
# `chain` — число, выраженное 0 или 1, которое показывает, является ли заведение сетевым (для маленьких сетей могут встречаться ошибки);
#
# `district` — административный район, в котором находится заведение, например Центральный административный округ;
#
# `seats` — количество посадочных мест.

# %% [markdown]
# # План работы

# %% [markdown]
# 1. Изучение данных.
#
#
# 2. Предобработка данных:
#
# *- поиск и обработка дубликатов*
#
# *- поиск и обработка пропусков*
#
# *- мсоздание дополнительных столбцов*
#
# `street` , `is_24/7`
#
#
# 3. Анализ данных
#
# *- Количество объектов общественного питания по категориям*
#
# *- Количество посадочных мест в местах по категориям*
#
# *- Соотношение сетевых и несетевых заведений в датасете*
#
# *- Топ-15 популярных сетей в Москве*
#
# *- Административные районы Москвы присутствуют в датасете*
#
# *- Топ-15 улиц по количеству заведений*
#
# *- Улицы, на которых находится только один объект общепите*
#
# *- Медиана  среднего чека для каждого района*
#
# *И т.д.*
#
#
#  4. Исследование открытия кофейни
#
#
#  5. Вывод

# %% [markdown]
# ## Изучение данных

# %%
# !pip install matplotlib --user --upgrade --quiet --no-warn-script-location

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly import graph_objects as go
import folium
import json
from folium import Map, Choropleth
from folium import Map, Marker
from folium.plugins import MarkerCluster

# %%
try:
    path = 'C:\\Users\\79067\\Desktop\\DA\\work\\' # ввод локального адреса
    df = pd.read_csv(path + 'moscow_places.csv')
except:
    df = pd.read_csv('/datasets/moscow_places.csv')

# %%
df.head()
# Out:
#                    name  category                              address  \
# 0                WoWфли      кафе           Москва, улица Дыбенко, 7/1
# 1        Четыре комнаты  ресторан   Москва, улица Дыбенко, 36, корп. 1
# 2                 Хазри      кафе       Москва, Клязьминская улица, 15
# 3  Dormouse Coffee Shop   кофейня  Москва, улица Маршала Федоренко, 12
# 4             Иль Марко  пиццерия      Москва, Правобережная улица, 1Б
#
#                           district  \
# 0  Северный административный округ
# 1  Северный административный округ
# 2  Северный административный округ
# 3  Северный административный округ
# 4  Северный административный округ
#
#                                                hours        lat        lng  \
# 0                             ежедневно, 10:00–22:00  55.878494  37.478860
# 1                             ежедневно, 10:00–22:00  55.875801  37.484479
# 2  пн-чт 11:00–02:00; пт,сб 11:00–05:00; вс 11:00...  55.889146  37.525901
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8406 entries, 0 to 8405
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               8406 non-null   object
#  1   category           8406 non-null   object
#  2   address            8406 non-null   object
#  3   district           8406 non-null   object
#  4   hours              7870 non-null   object
#  5   lat                8406 non-null   float64
#  6   lng                8406 non-null   float64
#  7   rating             8406 non-null   float64
#  8   price              3315 non-null   object
#  9   avg_bill           3816 non-null   object
#  10  middle_avg_bill    3149 non-null   float64
#  11  middle_coffee_cup  535 non-null    float64
#  12  chain              8406 non-null   int64
#  13  seats              4795 non-null   float64
# dtypes: float64(6), int64(1), object(7)
# memory usage: 919.5+ KB

# %% [markdown]
# ## Предобработка данных.
# ### Поиск дубликатов.

# %%
df['name'] = df['name'].str.lower()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated(subset=['name','address'])]
# Out:
#                            name  category  \
# 1511                  more poke  ресторан
# 2420  раковарня клешни и хвосты   бар,паб
# 3109            хлеб да выпечка      кафе
#
#                                       address  \
# 1511  Москва, Волоколамское шоссе, 11, стр. 2
# 2420               Москва, проспект Мира, 118
# 3109              Москва, Ярцевская улица, 19
#
#                                      district  \
# 1511          Северный административный округ
# 2420  Северо-Восточный административный округ
# 3109          Западный административный округ
#
#                                                   hours        lat        lng  \
# 1511  пн-чт 09:00–18:00; пт,сб 09:00–21:00; вс 09:00...  55.806307  37.497566
# 2420  пн-чт 12:00–00:00; пт,сб 12:00–01:00; вс 12:00...  55.810677  37.638379
# 3109                                                NaN  55.738449  37.410937
#
#       rating price avg_bill  middle_avg_bill  middle_coffee_cup  chain  seats
# ...

# %%
df = df.drop_duplicates(subset=['name','address']).reset_index(drop=True)

# %%
df[df.duplicated(subset=['name','address'])]
# Out:
# Empty DataFrame
# Columns: [name, category, address, district, hours, lat, lng, rating, price, avg_bill, middle_avg_bill, middle_coffee_cup, chain, seats]
# Index: []

# %% [markdown]
# ### Поиск и обработка пропусков

# %%
df.isna().sum()
# Out:
# name                    0
# category                0
# address                 0
# district                0
# hours                 535
# lat                     0
# lng                     0
# rating                  0
# price                5088
# avg_bill             4587
# middle_avg_bill      5254
# middle_coffee_cup    7868
# chain                   0
# seats                3611
# dtype: int64

# %%
df['hours'] = df['hours'].fillna('нет данных')
df.isna().sum()
# Out:
# name                    0
# category                0
# address                 0
# district                0
# hours                   0
# lat                     0
# lng                     0
# rating                  0
# price                5088
# avg_bill             4587
# middle_avg_bill      5254
# middle_coffee_cup    7868
# chain                   0
# seats                3611
# dtype: int64

# %% [markdown]
# Комментарий: Обнаружены пропуски занчений в столбцах `hours`, `price`, `avg_bill`, `middle_avg_bill`, `middle_coffee_cup`, `seats`.  Заменили пропуски в `hours` на 'нет данных'
#
# Нет возможности найти адекватную замену пропускам.
# Удалять стоки с прокпусками не будем, так как эти данные пригодятся нам в дальнейших исследованиях.

# %% [markdown]
# ### Аномальные значения

# %%
df_0 = df[df['chain']==0]
df_0['name'].value_counts().head(10)
# Out:
# кафе             189
# шаурма            43
# ресторан          34
# столовая          28
# бистро            12
# кофейня           12
# кафе-столовая      9
# буфет              8
# трапезная          7
# шашлычная          6
# Name: name, dtype: int64

# %% [markdown]
# Комментраий: несетевые кафе могут иметь одинаковые названия, исправять не будем.

# %%
df_1  = df[df['chain']==1].groupby('name')['category'].count().reset_index() #количество одноименных заведений среди сетей
df_1_anreal = df_1.query('category==1')['name'].unique()  #список названий единичных заведеий отмеченных сетями

df.loc[df['name'].isin(df_1_anreal),'chain'] = 0

# %% [markdown]
# Комментарий: заменили 1 на 0 в столбце `chain` у заведений, названия которых не повторяются.
#
# Заменим значения в столбце с сетями для дальнейшей удобной работы:

# %%
df.loc[df['chain']==0,'chain'] = 'Индивидуальное'
df.loc[df['chain']==1,'chain'] = 'Сетевое'

# %% [markdown]
# ### Добавление новых столбцов

# %% [markdown]
#  - добавим столбец `street` с названиями улиц

# %%
set(df['address'])
# Out:
# {'Москва, Новосущёвская улица, 26А',
#  'Москва, улица Пресненский Вал, 8к3',
#  'Москва, Авиамоторная улица, 39',
#  'Москва, Алма-Атинская улица, 1',
#  'Москва, Большая улица',
#  'Москва, Чертановская улица, 40, корп. 1',
#  'Москва, Лермонтовский проспект, 6',
#  'Москва, Новочерёмушкинская улица, 12',
#  'Москва, Краснодонская улица, 39А',
#  'Москва, Новоясеневский проспект, 1, стр. 4',
#  'Москва, улица Кржижановского, 20/30к1',
#  'Москва, улица Докукина, 10, стр. 11',
#  'Москва, Уральская улица, 6, корп. 1',
#  'Москва, улица Гастелло, 41',
#  'Москва, Ферганский проезд, 7, корп. 6',
#  'Москва, Смоленская улица, 5',
#  'Москва, Большая Новодмитровская улица, 36, стр. 7',
#  'Москва, Восточный административный округ, район Измайлово',
#  'Москва, улица Верхняя Масловка, 2',
#  'Москва, Мясницкая улица, 11',
#  'Москва, Семёновский переулок, 6',
#  'Москва, Симферопольский проезд, 7',
#  'Москва, Зеленодольская улица, 7, корп. 2',
# ...

# %%
def get_first_value(s):
    values = s.split(',')
    return values[1]

df['street'] = df['address'].apply(get_first_value)

# %% [markdown]
#  - добавим столбец `is_24/7`

# %%
def hour_work(hw):
    if 'круглосуточно' in hw and 'ежедневно' in hw:
        return True
    else: return False
    
df['is_24/7'] = df['hours'].apply(hour_work)

# %% [markdown]
# ## Анализ данных

# %%
df.describe()
# Out:
#                lat          lng       rating  middle_avg_bill  \
# count  8403.000000  8403.000000  8403.000000      3149.000000
# mean     55.750096    37.608604     4.229894       958.053668
# std       0.069664     0.098583     0.470426      1009.732845
# min      55.573942    37.355651     1.000000         0.000000
# 25%      55.705018    37.538637     4.100000       375.000000
# 50%      55.753407    37.605260     4.300000       750.000000
# 75%      55.795028    37.664810     4.400000      1250.000000
# max      55.928943    37.874466     5.000000     35000.000000
#
#        middle_coffee_cup        seats
# count         535.000000  4792.000000
# mean          174.721495   108.361436
# std            88.951103   122.841130
# min            60.000000     0.000000
# 25%           124.500000    40.000000
# 50%           169.000000    75.000000
# 75%           225.000000   140.000000
# max          1568.000000  1288.000000

# %%
df.boxplot('seats');

# %%
df[df['seats']>500].head(20)
# Out:
#                                      name  category  \
# 1326                                  нам   бар,паб
# 1351                        максима пицца  пиццерия
# 1355                           страдивари  ресторан
# 1367                             академия  пиццерия
# 1380                      север-метрополь   кофейня
# 1385                    чайхона на соколе      кафе
# 1393  кулинарная лавка братьев караваевых      кафе
# 1442                  abc coffee roasters   кофейня
# 1446                         9 bar coffee   кофейня
# 1464                              находка  ресторан
# 1475                          falko pizza  пиццерия
# 1498                      brooklyn coffee   кофейня
# 1547                        french bakery      кафе
# 1671                             ача-чача  ресторан
# 1765                       золотая бухара  ресторан
# 1825                           волконский  булочная
# 1837                        take and wake   кофейня
# ...

# %% [markdown]
# *Заметка: заведения с большим количеством посаочных мест, чаще всего нахдятся в фуд-кортах. То етсь несколько заведений имеют общую посадочную зону и у каждого она записана как принадлежащая этому заведению*

# %% [markdown]
# ### Распределение заведений по категориям

# %%
plt.figure(figsize=(9, 3))
ax = sns.barplot(x='lat', y='category', data=df, order=df['category'].value_counts().index, estimator=len, orient='h',palette='YlOrBr_r')
ax.set_title('Количество объектов в по категориям')
ax.set_xlabel('Количество, шт.')
ax.set_ylabel('Категория')
for i in ax.containers:
    ax.bar_label(i,);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_31/3987950663.py in <module>
#       5 ax.set_ylabel('Категория')
#       6 for i in ax.containers:
# ----> 7     ax.bar_label(i,);
#
# AttributeError: 'AxesSubplot' object has no attribute 'bar_label'

# %% [markdown]
# ### Количество посадочных мест

# %%
plt.figure(figsize=(7, 4))
ax = sns.barplot(x='seats', y='category', data=df,estimator=np.median,
                 order=df.groupby('category')['seats'].median().sort_values(ascending=False).index,
                 orient='h',ci=None,palette='YlOrBr_r')
ax.set_title('Медианное количество посадочных мест в каждой категории')
ax.set_xlabel('Количество, шт.')
ax.set_ylabel('Категория')
for i in ax.containers:
    ax.bar_label(i,);

# %%
plt.figure(figsize=(5, 10))
ax = sns.violinplot(x='seats', y='category', data=df, palette="YlOrBr") 
ax.set_title('Распределение посадочных мест в каждой категории')
ax.set_xlabel('Количество посадочных мест')
ax.set_ylabel('Категория');

# %% [markdown]
# Комментарий:  самое большое количество заведений относится к категории "кафе", далее идут "ресторан" и "кофейня".
# Самой малочисленной категорией оказались "булочные".
#
# По количествам посадочных мест лидирует категория "ресторан", далее "бары, пабы" и "кофейни", меньше всего посадочных мест также в среднем у категории "булочная".

# %% [markdown]
# ### Сетевые и одиночные заведения

# %%
chain_total = df.groupby('chain')['name'].count().reset_index()

# %%
fig = go.Figure(data=[go.Pie(labels=chain_total['chain'], values=chain_total['name'],
                            hole=.3)])
fig.show();

# %%
plt.figure(figsize=(10, 5))
ax = sns.barplot(x='lat', y='category',hue='chain', data=df, order=df['category'].
                 value_counts().index, estimator=len, orient='h',palette='YlOrBr'
                 )
ax.set_title('Расределение сетевых и несетевых заведений по категориям')
ax.set_xlabel('Количество, шт.')
ax.set_ylabel('Категория')

for i in ax.containers:
    ax.bar_label(i,);

# %% [markdown]
# Комментарий: В целом индивидуальных заведений не принадлежащих сетям больше, чем сетевых.
# Сетевые заведения преобладают в категориях "кофейня","пиццерия" и "булочная", в остальных категориях перевес в сторону индивидуальных заведений.

# %% [markdown]
# ### Топ 15 сетевых заведений

# %%
chain_top = (df.query('chain == "Сетевое"').query('name != "хинкальная"').groupby('name')
                              .agg(count_object=('name', 'count'))
                              .sort_values(by='count_object', ascending=False).reset_index())[:15]

# %%
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='count_object', y='name', data=chain_top,  orient='h',palette='YlOrBr_r')
ax.set_title('Топ-15 сетевых заведений')
ax.set_xlabel('Количество, шт.')
ax.set_ylabel('Название сети')

for i in ax.containers:
    ax.bar_label(i,);

# %%
top_names = chain_top['name'].unique() # список сетей топ-15
top_names_data = df.query('chain == "Сетевое"').query('name in @top_names') #данные по сетевым ресторанам  из топ-15
res = top_names_data.groupby(['name','category']).count().reset_index() # сети с категориями

# %%
fig = px.bar(res, x='address', y='name', color='category',
             hover_name='address',
             title='Категории сетевых заведений')
fig.show()

# %%
order_rating_15 = top_names_data.groupby('name')['rating'].median().sort_values(ascending=False).index

plt.figure(figsize=(10, 7))
ax = sns.boxplot(x='rating', y='name', data=top_names_data,  orient='h',order=order_rating_15, palette='hls')
ax.set_title('Распределение рейтингов самых популярных сетей')
ax.set_xlabel('Ретинг')
ax.set_ylabel('Название сети');

# %% [markdown]
# Комментарий: Самая крупная сеть в Москве - Шоколадница, далее по количеству заведений идут пиццерии Домино'с  Додо.
# Большая часть сетей из топ-15 относится к среднему ценовому сегменту.
# В основном это  кофейни,пиццерии, рестораны.
#
# При этом лучшие рейтинги у Буханки,Лавки братьев Караваевыхи, самый низкий рейтинг у Яндекс лавки.

# %% [markdown]
# ### Администратиные районы

# %%
df_district = df.groupby(['district'])['name'].count().sort_values(ascending=False).reset_index()
df_district

# %%
df_group = df.groupby(['district', 'category'])['name'].count().reset_index()

df_group['district'] = df_group['district'].replace('Северо-Западный административный округ','СЗАО')
df_group['district'] = df_group['district'].replace('Юго-Западный административный округ','ЮЗАО')
df_group['district'] = df_group['district'].replace('Юго-Восточный административный округ','ЮВАО')
df_group['district'] = df_group['district'].replace('Восточный административный округ','ВАО')
df_group['district'] = df_group['district'].replace('Западный административный округ','ЗАО')
df_group['district'] = df_group['district'].replace('Северо-Восточный административный округ','СВАО')
df_group['district'] = df_group['district'].replace('Южный административный округ','ЮАО')
df_group['district'] = df_group['district'].replace('Северный административный округ','САО')
df_group['district'] = df_group['district'].replace('Центральный административный округ','ЦАО')

# %%
df_group.columns = ['Округ', 'Категория', 'Количество']

# %%
import plotly.express as px
fig = px.sunburst(df_group, path=['Округ', 'Категория'], values='Количество')
fig.show()

# %% [markdown]
# Комментарий: Самое большое количество заведений общепита находится в ЦАО(2242шт.), по категориям в ЦАО лидируют рестораны (670 шт.).
# В СЗАО меньше всего заведений (409), лидируюшей категорией в данном округе являются кафе(115 шт) и рестораны (109 шт.).
# Во всех округах кроме ЦАО лидирует катгория "кафе", в ЦАО самая популярная категоря "ресторан".

# %%
fig = px.bar(df_group, y='Округ', x='Количество', color='Категория',
             hover_name='Количество',
             title='Распределение заведений по округам',
            width=700, height=400)
fig.show()

# %% [markdown]
# ### Рейтинг по категориям

# %%
category_rating = df.groupby('category')['rating'].median().sort_values(ascending=False).reset_index()
category_rating

# %%
order_rating = df.groupby('category')['rating'].median().sort_values(ascending=False).index

plt.figure(figsize=(7,5))
ax = sns.boxplot(x='rating', y='category', data=df, order = order_rating, orient='h',palette='hls')
ax.set_title('Распределние рейтингa заведений в каждой категории')
ax.set_xlabel('Средний рейтинг')
ax.set_ylabel('Категория');

# %%
plt.figure(figsize=(7,5))
ax = sns.barplot(x='rating', y='category', data=df, order = order_rating,estimator=np.median, orient='h',ci=False,palette='hls')
ax.set_title('Медианный рейтинг заведений в каждой категории')
ax.set_xlabel('Рейтинг')
ax.set_ylabel('Категория')

for i in ax.containers:
    ax.bar_label(i,);

# %% [markdown]
# Комментарий: Медианные рейтинги у всех групп заведений отличаются не существенно, чуть ниже(4.2) у категорий кафе и быстрое притание, чуть выше значения у категории паб,бар(4.4).

# %% [markdown]
# ### Средний рейтинг заведений по районам

# %%
df_geo = df.groupby('district')['rating'].median().sort_values(ascending=False).reset_index()
df_geo

# %%
state_geo = r'https://code.s3.yandex.net/data-analyst/admin_level_geomap.geojson'

moscow_lat, moscow_lng = 55.751244, 37.618423


m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)


Choropleth(
    geo_data=state_geo,
    data=df_geo,
    columns=['district', 'rating'],
    key_on='feature.name',
    fill_color='YlOrBr',
    fill_opacity=0.8,
    legend_name='Медианный рейтинг заведений по районам',
).add_to(m)


m

# %% [markdown]
# Комментарий: Лучший рейтинг у ЦАО (4.4), Худший у ЮВАО и СВАО(4.2)

# %%
moscow_lat, moscow_lng = 55.751244, 37.618423

m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)
marker_cluster = MarkerCluster().add_to(m)

def create_clusters(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['address']}",
    ).add_to(marker_cluster)

df.apply(create_clusters, axis=1)

m

# %%
df_street = df.groupby('street')['name'].count().sort_values(ascending=False).reset_index()
df_street_top = df_street[:15] 
top_streets = df_street_top['street'].unique() # список топ-15 улиц с самым большим количеством заведений

df_top_streets = df.query('street in @top_streets')

streets = df_top_streets.groupby(['street','category'])['name'].count().reset_index()

# %%
fig = px.bar(streets, x='name', y='street', color='category',
             hover_name='name',
             title='Топ 15 улиц, состав',
            width=1000, height=500)
fig.show()

# %% [markdown]
# Комментарий: Проспект Мира - лидирующая улица по численности заведений общественного питания(183 шт)
# За ней идут Профсоюзная улица и проспект Вернадского, последней в топ-15 попала  Пятницкая улица с 48 заведениями.

# %% [markdown]
# ### Улицы с одним заведением

# %%
one_res_street = df_street[df_street['name'] == 1]['street'].unique()
one_res = df.query('street in @one_res_street') # данные по "одиноким" заведениям

# %%
one_res_cat = one_res.groupby('category')['name'].count().reset_index() # количество "одиноких" заведений по категориям 
df_cat = df.groupby('category')['name'].count().reset_index() # общее количество заведений по категориям
one_res_cat['total_sdape'] = round(one_res_cat['name']/df_cat['name']*100) # процент "одиноких" от общего числа заведений
one_res_cat = one_res_cat.sort_values(by ='total_sdape', ascending=False)


plt.figure(figsize=(5, 3))
ax = sns.barplot(x='total_sdape', y='category', data=one_res_cat, orient='h', palette='hls')
ax.set_title('Доля "одиноких" заведений от общего числа по категорям')
ax.set_xlabel('% от общего числа заведений в категории')
ax.set_ylabel(' ')

for i in ax.containers:
    ax.bar_label(i,);
    
    
one_res_dist = one_res.groupby('district')['name'].count().reset_index() # количество "одиноких" заведений по районам 
df_dist = df.groupby('district')['name'].count().reset_index() # общее количество заведений по районам
one_res_dist['total_sdape'] = round(one_res_dist['name']/df_dist['name']*100) # процент "одиноких" от общего числа заведений
one_res_dist = one_res_dist.sort_values(by ='total_sdape', ascending=False)

plt.figure(figsize=(5, 3))
ax = sns.barplot(x='total_sdape', y='district', data=one_res_dist, orient='h', palette='hls')
ax.set_title('Доля "одиноких" заведений от общего числа по районам')
ax.set_xlabel('% от общего числа заведений в районе')
ax.set_ylabel(' ')

for i in ax.containers:
    ax.bar_label(i,);

# %% [markdown]
# Комментарий: В процентном соотношении от общего количества заведений, большая доля "одиноких" заведений среди столовых, самая маленькая доля среди пиццерий.
# По одному заведению на улице чаще встречается в ВАО, реже всего такие заведения из общего числа заведений попадаются в ЮЗАО.

# %% [markdown]
# ### Медианные значения среднего чека

# %%
df_bill = df.groupby('district',as_index=False)['middle_avg_bill'].median().sort_values(by='middle_avg_bill')
df_bill

# %%
from folium import Map, Choropleth

state_geo = r'https://code.s3.yandex.net/data-analyst/admin_level_geomap.geojson'

moscow_lat, moscow_lng = 55.751244, 37.618423


m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)


Choropleth(
    geo_data=state_geo,
    data=df_bill,
    columns=['district', 'middle_avg_bill'],
    key_on='feature.name',
    fill_color='YlOrBr',
    fill_opacity=0.8,
    legend_name='Медианные значения среднего чека заведений по районам',
).add_to(m)


m

# %% [markdown]
# Комментарий: Предсказуемо, средний чек с самым большим значением ЦАО и ЗАО, самые маленькие значениия у ЮВАО, СВАО и ЮАО.

# %% [markdown]
# ## Выводы.
#
# - Cамое <b> большое количество заведений</b> относится к категории <b>"кафе"</b>, далее идут "ресторан" и "кофейня". Самой <b>малочисленной</b> категорией оказались <b>"булочные"</b>.
#
#
# - <b>По количествам посадочных мест лидирует категория "ресторан"</b>, далее "бары, пабы" и "кофейни", <b>меньше всего посадочных мест</b> также в среднем у категории <b>"булочная"</b>.Нужно учесть что заведения с большим количеством посадочных мест, чаще всего нахдятся в фуд-кортах. То етсь несколько заведений имеют общую посадочную зону и у каждого она записана как принадлежащая этому заведению
#
# - Количество заведений входящих в <b>сети</b> значительно меньше(<b>37,4%</b> от общео числа) числа заведений <b>не принадлежащих сетям(62,6%)</b>
#
#
# - При этом <b>сетевые заведения преобладают</b> в категориях <b>"кофейня"</b>(715 против 698),<b>"пиццерия"</b>(325 против 308) и <b>"булочная"</b> (156 против 100), в остальных категориях перевес в сторону индивидуальных заведений.
#
#
# - <b>Самая крупная сеть</b> в Москве - <b>Шоколадница</b>(120 шт), далее по количеству заведений идут пиццерии Домино'с(76шт) и  Додо(74 шт).
#
#
# - Большая часть сетей из топ-15 относится к среднему ценовому сегменту. В основном это кофейни,пиццерии, рестораны.
#
#
# - При этом из Топ-15 сетевых заведений <b>лучшие рейтинги</b> у <b>Буханки</b>(4,4) и <b>Лавки братьев Караваевыхи</b>(4,4)  самый низкий рейтинг у Яндекс лавки(4,0).
#
#
# - Самое <b>большое количество заведений</b> общепита находится в <b>ЦАО</b>(2242шт.), по категориям в ЦАО лидируют рестораны (670 шт.). <b>В СЗАО меньше всего заведений</b> (409), лидируюшей категорией в данном округе являются кафе(115 шт) и рестораны (109 шт.).
#
#
# - Медианные рейтинги у всех групп заведений отличаются не существенно, чуть ниже(4.2) у категорий кафе и быстрое притание, чуть выше значения у категории паб,бар(4.4).
#
# - <b>Лучший рейтинг в ЦАО </b>(4.4). <b>Худший у ЮВАО и СВАО</b>(4.2)
#
# - <b>Проспект Мира</b> - лидирующая улица по численности заведений общественного питания(183 шт) За ней идут Профсоюзная улица и проспект Вернадского, последней в топ-15 попала  Пятницкая улица с 48 заведениями.
#
#
# - В процентном соотношении от общего количества заведений, большая доля "одиноких" заведений среди столовых, самая маленькая доля среди пиццерий.
#
#
# - По одному заведению на улице чаще встречается в ВАО, реже всего такие заведения из общего числа заведений попадаются в ЮЗАО.
#
#
# - <b>Cредний чек</b> с самым <b>большим</b> значением <b>ЦАО и ЗАО</b>, самые <b>маленькие значениия у ЮВАО, СВАО и ЮАО</b>.

# %% [markdown]
# ## Открытие коффейни

# %% [markdown]
# Из предыдущгео исследования мы знаем, что категория кофеен в Москве находится на третьем месте по численности (1413 шт.)
# Среднее количество посадочных мест в данной категории-80
#  При этом несетевых  кофеен 698 шт, тогда как сетям принадлежат 715 заведений.
# 5 сетей кофеен входят в топ 15 популярных сетей и еще 2 сети имеют кофейни с своем составе.
# В каждом районе Москвы есть кофейни. Больше всего в ЦАО(428 шт.), меньше всего в СЗАО(62 шт.)
#
# Кофейни занимают второе мето по количеству заведений в САО,третье место в остальных округах.
#
# Медианный рейтинг у кофеен 4.3
#
# Рассмотрим данную категорию подробнее

# %%
df_ch = df[df['category']=='кофейня']
df_ch.head()

# %% [markdown]
# ### Распределение кофеен по округам

# %%
district_ch = df_ch.groupby('district')['name'].count().sort_values().reset_index()
district_ch

# %%
m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)
marker_cluster = MarkerCluster().add_to(m)

def create_clusters(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['address']}",
    ).add_to(marker_cluster)

df_ch.apply(create_clusters, axis=1)

m

Choropleth(
    geo_data=state_geo,
    data=district_ch,
    columns=['district', 'name'],
    key_on='feature.name',
    fill_color='YlOrBr',
    fill_opacity=0.5,
    legend_name='Количество заведений по районам',
).add_to(m)


m

# %% [markdown]
# Комментарий: Районом с максимальным количеством кофеен является ЦАО, меньше всего кофеен в СЗАО, ЮВАО и ЮЗАО.

# %% [markdown]
# ### Круглосуточные кофейни

# %%
ch_24 = df_ch[df_ch['is_24/7']== True]

m = Map(location=[moscow_lat, moscow_lng], zoom_start=10)
marker_cluster = MarkerCluster().add_to(m)

def create_clusters(row):
    Marker(
        [row['lat'], row['lng']],
        popup=f"{row['name']} {row['address']}",
    ).add_to(marker_cluster)

ch_24.apply(create_clusters, axis=1)

m

# %% [markdown]
# ### Рейтинги кофеен

# %%
df_ch['rating'].describe()

# %% [markdown]
# Коментарий: Большая часть кофеен имеют рейтинги в диапазоне 4.1-4.4

# %%
df_ch.groupby('district')['rating'].median().sort_values().reset_index()

# %% [markdown]
# Комментарий: Медианные рейтинги по районам практически одинаковы(4.3), отстает только ЗАО со значением 4.2.

# %%
df_ch.head(1)

# %%
median_cup = df_ch.groupby('district')['middle_coffee_cup'].median().sort_values(ascending=False).reset_index()

plt.figure(figsize=(7, 3))
ax = sns.barplot(x='middle_coffee_cup', y='district', data=median_cup, orient='h', palette='YlOrBr_r')
ax.set_title('Медианная стоимость чашки кофе')
ax.set_xlabel('Стоимость, руб.')
ax.set_ylabel(' ')

for i in ax.containers:
    ax.bar_label(i,);

# %% [markdown]
# Комментарий: В зависимости от района, в котором планируется открытие кофейни при выборе ценовой политики можно ориентироваться на средние значения стоимости чашки кофе по району. Если кофейня должна быть "доступной", то вероятно цена должна быть немного ниже или равна средней.

# %%
street_ch = df_ch.groupby('street')['name'].count().sort_values(ascending=False).reset_index()
name_street_ch = street_ch['street'].unique() # список улиц на которых есть кофейни

street_without_ch = df_street.query ('street not in @name_street_ch').query('name!=1')[:14]
street_without_ch = street_without_ch.sort_values(by='name',ascending=False)

street_without_ch

# %% [markdown]
# Комментарий: список улиц, с большим количеством заведений,вероятно с хорошей проходимостью на которых при этом нет кофеен

# %% [markdown]
# Ссылка на презентацию: https://disk.yandex.ru/i/o7Kb9x3hBEhkFA
